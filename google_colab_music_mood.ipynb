# %%
# Mount into drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Change directory to the package folder
# %cd '/content/drive/My Drive/music_mood'
# Verify the contents of the current folder
# !ls
# Out:
# /content/drive/My Drive/music_mood
#  agents			  google_colab_music_mood.ipynb
# 'audio load.ipynb'	  losses
# 'audio load-LSTM.ipynb'   main.py
#  checkpoint		  models
#  condacolab_install.log   multi_class_mood_classifier.ipynb
#  config			  multi_class_mood_classifier-mp3.ipynb
#  data			  README.md
#  datasets		  requirements.txt
#  environment.yml	 'song mood.ipynb'
#  figures		  utils
# 'get playlists.ipynb'

# %%
# !python -m pip --version
# !python -m pip install ipykernel
# Out:
# pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 138 kB 9.3 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 8.3 kB/s
# ...
#      |████████████████████████████████| 9.5 MB 72.9 MB/s
# ...
#      |████████████████████████████████| 61 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 27.4 MB 90 kB/s
# ...
#      |████████████████████████████████| 76 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 33.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: requests
# ...

# %%
# !pip install gputil
# !pip install psutil
# !pip install humanize
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7410 sha256=fcae3a75ac6df2fdde99a069f63d6746985ae8b1ab69692e5bb2d16f2177bcd5
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built gputil
# ...
# CPU RAM Free: 12.7 GB
# GPU 0 ... Mem Free: 15109MB / 15109MB | Utilization   0%

# %%
import os,sys,humanize,psutil,GPUtil
# Define function
def mem_report():
  print("CPU RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ))
  GPUs = GPUtil.getGPUs()
  for i, gpu in enumerate(GPUs):
    print('GPU {:d} ... Mem Free: {:.0f}MB / {:.0f}MB | Utilization {:3.0f}%'.format(i, gpu.memoryFree, gpu.memoryTotal, gpu.memoryUtil*100))
# Execute function
mem_report()
# Out:
# CPU RAM Free: 12.6 GB
# GPU 0 ... Mem Free: 15109MB / 15109MB | Utilization   0%

# %%
# Create csv model
# !python main.py  --config config/audio_feature_config_csv.json
# Out:
# ********RUNNING ON:  cuda:0
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py:4569: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# MulticlassClassification(
#   (layer_1): Linear(in_features=11, out_features=512, bias=True)
#   (layer_2): Linear(in_features=512, out_features=128, bias=True)
#   (layer_3): Linear(in_features=128, out_features=64, bias=True)
#   (layer_out): Linear(in_features=64, out_features=4, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# Create csv model
# !python main.py  --config config/audio_feature_config_mp3_lstm.json
# "epochs": 100,
#     "batch_size": 32,
#     "learning_rate":0.005,
# "hidden_dim": 256,
#     "num_layer": 2,
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([1024, 128])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([1024, 256])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([64, 256])
# torch.Size([64])
# torch.Size([4, 64])
# torch.Size([4])
# LSTM(
#   (lstm): LSTM(128, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=4, bias=True)
# )
# Begin Training
#   0% 0/100 [00:00<?, ?it/s]
# Epoch 001: |                 Train Loss: 1.27452 |                 Val Loss: 0.98437 |                 Train Acc: 38.250|                 Val Acc: 52.910
#   1% 1/100 [00:32<54:03, 32.76s/it]
# Epoch 002: |                 Train Loss: 1.06277 |                 Val Loss: 0.93352 |                 Train Acc: 54.125|                 Val Acc: 51.587
#   2% 2/100 [01:05<53:24, 32.69s/it]
# ...

# %%
# Create csv model
# !python main.py  --config config/audio_feature_config_mp3_rnn.json
# Out:
# ********RUNNING ON:  cuda:0
# RNN(
#   (rnn): RNN(128, 128, batch_first=True)
#   (layer_out): Linear(in_features=128, out_features=4, bias=True)
# )
# Begin Training
#   0% 0/100 [00:00<?, ?it/s]
# Epoch 001: |                 Train Loss: 2.04944 |                 Val Loss: 1.16536 |                 Train Acc: 25.500|                 Val Acc: 54.233
#   1% 1/100 [00:19<32:33, 19.74s/it]
# Epoch 002: |                 Train Loss: 1.29314 |                 Val Loss: 1.05309 |                 Train Acc: 44.500|                 Val Acc: 54.497
#   2% 2/100 [00:38<31:43, 19.43s/it]
# Epoch 003: |                 Train Loss: 1.23120 |                 Val Loss: 0.91200 |                 Train Acc: 45.500|                 Val Acc: 54.762
#   3% 3/100 [00:58<31:43, 19.63s/it]
# Epoch 004: |                 Train Loss: 1.18749 |                 Val Loss: 0.94459 |                 Train Acc: 45.500|                 Val Acc: 55.556
#   4% 4/100 [01:18<31:11, 19.49s/it]
# ...

# %%
# Create csv model
# !python main.py  --config config/ensemble_config_lstm.json
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([1024, 128])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([1024, 256])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([64, 256])
# torch.Size([64])
# torch.Size([4, 64])
# torch.Size([4])
# MyEnsemble(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Linear(in_features=64, out_features=4, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# Create csv model
# !python main.py  --config config/ensemble_config_rnn.json
# Out:
# ********RUNNING ON:  cuda:0
# MyEnsemble(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Linear(in_features=64, out_features=4, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (modelB): RNN(
#     (rnn): RNN(128, 128, batch_first=True)
#     (layer_out): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (classifier): Linear(in_features=8, out_features=4, bias=True)
# )
# Begin Training
# ...

# %%
# !python main.py  --config config/ensemble2_config_lstm.json
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([1024, 128])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([1024, 256])
# torch.Size([1024, 256])
# torch.Size([1024])
# torch.Size([1024])
# torch.Size([64, 256])
# torch.Size([64])
# torch.Size([4, 64])
# torch.Size([4])
# MyEnsemble2(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Identity()
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (modelB): LSTM(
# ...

# %%
# !python main.py  --config config/ensemble2_config_rnn.json
# Out:
# ********RUNNING ON:  cpu
# MyEnsemble2(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Identity()
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (modelB): RNN(
#     (rnn): RNN(128, 128, batch_first=True)
#     (layer_out): Identity()
#   )
#   (classifier): Linear(in_features=192, out_features=4, bias=True)
# )
# Begin Training
# ...

# %%
# !python main.py  --config config/audio_feature_config_mp3_lstm.json
# "hidden_dim": 512,
#     "num_layer": 1,
#         "epochs": 100,
#     "batch_size": 128,
#     "learning_rate": 0.00003,
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([2048, 128])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([64, 512])
# torch.Size([64])
# torch.Size([4, 64])
# torch.Size([4])
# LSTM(
#   (lstm): LSTM(128, 512, batch_first=True)
#   (fc): Linear(in_features=512, out_features=64, bias=True)
#   (layer_out): Linear(in_features=64, out_features=4, bias=True)
# )
# Begin Training
#   0% 0/100 [00:00<?, ?it/s]
# Epoch 001: |                 Train Loss: 1.39029 |                 Val Loss: 1.38878 |                 Train Acc: 23.000|                 Val Acc: 24.339
#   1% 1/100 [00:10<17:49, 10.80s/it]
# Epoch 002: |                 Train Loss: 1.38752 |                 Val Loss: 1.38619 |                 Train Acc: 24.500|                 Val Acc: 24.339
#   2% 2/100 [00:20<17:00, 10.42s/it]
# Epoch 003: |                 Train Loss: 1.38662 |                 Val Loss: 1.38311 |                 Train Acc: 25.000|                 Val Acc: 24.339
# ...

# %%
# !python main.py  --config config/ensemble2_config_lstm.json
# "hidden_dim": 512,
#     "num_layer": 1,
#         "epochs": 100,
#     "batch_size": 64,
#     "learning_rate": 0.00003,
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([2048, 128])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([64, 512])
# torch.Size([64])
# torch.Size([4, 64])
# torch.Size([4])
# MyEnsemble2(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Identity()
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (modelB): LSTM(
#     (lstm): LSTM(128, 512, batch_first=True)
# ...

# %%
# !python main.py  --config config/audio_feature_config_mp3_lstm.json
# "hidden_dim": 512,
#     "num_layer": 1,
    # "epochs": 100,
    # "batch_size": 128,
    # "learning_rate": 0.00003,
    # 128 2nd to last layer size
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([2048, 128])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([128, 512])
# torch.Size([128])
# torch.Size([4, 128])
# torch.Size([4])
# LSTM(
#   (lstm): LSTM(128, 512, batch_first=True)
#   (fc): Linear(in_features=512, out_features=128, bias=True)
#   (layer_out): Linear(in_features=128, out_features=4, bias=True)
# )
# Begin Training
#   0% 0/100 [00:00<?, ?it/s]
# Epoch 001: |                 Train Loss: 1.38954 |                 Val Loss: 1.38825 |                 Train Acc: 17.500|                 Val Acc: 19.841
#   1% 1/100 [00:09<15:36,  9.46s/it]
# Epoch 002: |                 Train Loss: 1.38692 |                 Val Loss: 1.38488 |                 Train Acc: 18.500|                 Val Acc: 23.280
#   2% 2/100 [00:18<14:53,  9.12s/it]
# Epoch 003: |                 Train Loss: 1.38374 |                 Val Loss: 1.38168 |                 Train Acc: 16.500|                 Val Acc: 27.249
# ...

# %%
# !python main.py  --config config/ensemble2_config_lstm.json
# used blake's trained lstm
# Out:
# ********RUNNING ON:  cuda:0
# torch.Size([2048, 128])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([128, 512])
# torch.Size([128])
# torch.Size([4, 128])
# torch.Size([4])
# MyEnsemble2(
#   (modelA): MulticlassClassification(
#     (layer_1): Linear(in_features=11, out_features=512, bias=True)
#     (layer_2): Linear(in_features=512, out_features=128, bias=True)
#     (layer_3): Linear(in_features=128, out_features=64, bias=True)
#     (layer_out): Identity()
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (modelB): LSTM(
#     (lstm): LSTM(128, 512, batch_first=True)
# ...
